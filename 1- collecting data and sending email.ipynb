# %%
#Automação de Sistemas e Processos com Pyautogui e pyperclip
#ATENÇÃO! o pointer pode variar dependendo do motitor

# %%
#Código que serve de cooldown entre um comando e outro dentro do PYAUTOGUI
pya.pause = 2

#código utilizado para pegar a localização exata do mouse
tm.sleep(5)
print(pya.position())
# Out:
# Point(x=1024, y=361)

# %%
#importando bibliotecas
import pyautogui as pya
import pyperclip as pyc
import pandas as pan
import time as tm

# %%
pya.hotkey("ctrl", "t")
pyc.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing")
pya.hotkey("ctrl", "v")
pya.press("enter")

tm.sleep(5)

pya.click(x=551, y=374, clicks=2)
tm.sleep(2)
pya.click(x=2339, y=369, clicks=1)
tm.sleep(10)

# %%
#IMPORTNATE - para que a leitura ocorra corretamente, é necessário troccar o nome do user para o respectino nome de usuário de sua máquina.
tabela = pan.read_excel(r"C:\Users\engba\Downloads\Vendas - Dez.xlsx")
display(tabela)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#Calculando os dados da planilha
faturamento = tabela["Valor Final"].sum()
print(faturamento)
quantidade = tabela["Quantidade"].sum()
print(quantidade)
# Out:
# 2917311
# 15227

# %%
# abrir aba
pya.hotkey("ctrl", "t")

# entrar no link do email - https://mail.google.com/mail/u/0/#inbox
pyc.copy("https://mail.google.com/mail/u/0/#inbox")
pya.hotkey("ctrl", "v")
pya.press("enter")
tm.sleep(20)

# clicar no botão escrever
pya.click(x=202, y=185)
tm.sleep(5)

# preencher as informações do e-mail
pya.write("pythonimpressionador@gmail.com")
pya.press("tab") # selecionar o email
pyc.copy("Relatório de Vendas")
pya.hotkey("ctrl", "v")
pya.press("tab") # pular para o campo de assunto

texto = f"""
Boa tarde,

Segue relatório de vendas.
Faturamento: R${faturamento:,.2f}
Quantidade de produtos vendidos: {quantidade:,}

Att.,
Brittes.
Setor de vendas

Créditos:
Edte projeto foi realizado a partir um bootcamp da 
HASHTAG PROGRAMAÇÃO, você pode baixar o material completos deles a partir deste drive

"""



# formatação dos números (moeda, dinheiro)

pyc.copy(texto)
pya.hotkey("ctrl", "v")

# enviar o e-mail
#pya.hotkey("ctrl", "enter")
